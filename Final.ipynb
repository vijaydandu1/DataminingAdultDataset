# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaydandu1/DataminingAdultDataset/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Loading the dataset**

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns # for visualization
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")
np.random.seed(42)

df=  pd.read_csv("https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/West_Nile_Virus__WNV__Mosquito_Test_Results.csv")

# %%
df.head()
# Out:
#    SEASON YEAR  WEEK  TEST ID                  BLOCK  TRAP TRAP_TYPE  \
# 0         2014    39    40542  100XX W OHARE AIRPORT  T902    GRAVID
# 1         2016    37    44219  100XX W OHARE AIRPORT  T902    GRAVID
# 2         2017    33    45351  100XX W OHARE AIRPORT  T905    GRAVID
# 3         2017    33    45345  100XX W OHARE AIRPORT  T900    GRAVID
# 4         2016    37    44169            4XX W 127TH  T135    GRAVID
#
#                 TEST DATE  NUMBER OF MOSQUITOES    RESULT  \
# 0  09/25/2014 12:09:00 AM                     8  negative
# 1  09/15/2016 12:09:00 AM                    39  negative
# 2  08/17/2017 12:08:00 AM                    50  positive
# 3  08/17/2017 12:08:00 AM                    17  positive
# 4  09/15/2016 12:09:00 AM                    12  negative
#
#                   SPECIES  LATITUDE  LONGITUDE LOCATION
# 0  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 1  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 2  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 3  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 4  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN

# %% [markdown]
# ## **Transforming the attribute to numeric**

# %%
df['TRAP']= df['TRAP'].astype('category')
df['TRAP']= df['TRAP'].cat.codes

# %%
df.head()
# Out:
#    SEASON YEAR  WEEK  TEST ID                  BLOCK  TRAP TRAP_TYPE  \
# 0         2014    39    40542  100XX W OHARE AIRPORT   171    GRAVID
# 1         2016    37    44219  100XX W OHARE AIRPORT   171    GRAVID
# 2         2017    33    45351  100XX W OHARE AIRPORT   174    GRAVID
# 3         2017    33    45345  100XX W OHARE AIRPORT   169    GRAVID
# 4         2016    37    44169            4XX W 127TH   106    GRAVID
#
#                 TEST DATE  NUMBER OF MOSQUITOES    RESULT  \
# 0  09/25/2014 12:09:00 AM                     8  negative
# 1  09/15/2016 12:09:00 AM                    39  negative
# 2  08/17/2017 12:08:00 AM                    50  positive
# 3  08/17/2017 12:08:00 AM                    17  positive
# 4  09/15/2016 12:09:00 AM                    12  negative
#
#                   SPECIES  LATITUDE  LONGITUDE LOCATION
# 0  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 1  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 2  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 3  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 4  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN

# %% [markdown]
# ## **Standardizing the TRAP attribute**

# %%
unscaled_features = df[['TRAP']]
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Calculate μ & σ(fit) and apply the transformation(transform)
unscaled_features_array = sc.fit_transform(unscaled_features.values)

# Assign the scaled data to a DataFrame & use the index and columns arguments to keep your original indices and column names:
scaled_features = pd.DataFrame(unscaled_features_array, index=unscaled_features.index, columns=unscaled_features.columns)

scaled_features.head()
# Out:
#        TRAP
# 0  1.422334
# 1  1.422334
# 2  1.476493
# 3  1.386228
# 4  0.248881

# %% [markdown]
# ## **Transforming the second attribute from numeric to xs -- s -- m -- l -- xl.**

# %%
df.WEEK.describe()
# Out:
# count    29489.000000
# mean        31.073587
# std          4.533390
# min         20.000000
# 25%         28.000000
# 50%         31.000000
# 75%         35.000000
# max         40.000000
# Name: WEEK, dtype: float64

# %%
# Setting up our 5 buckets and their labels
buckets = [ 20, 28, 31, 35, 38, 40 ]
bucketlabels = ['xs', 's', 'm', 'l', 'xl']

# Using cut() to separate data into the buckets we have built
df['WEEK'] = pd.cut(df['WEEK'] , bins=buckets, labels=bucketlabels, include_lowest=True)

# Check if we have the new attribute 'buckets' at the end of our dataset
df.head()
# Out:
#    SEASON YEAR WEEK  TEST ID                  BLOCK  TRAP TRAP_TYPE  \
# 0         2014   xl    40542  100XX W OHARE AIRPORT   171    GRAVID
# 1         2016    l    44219  100XX W OHARE AIRPORT   171    GRAVID
# 2         2017    m    45351  100XX W OHARE AIRPORT   174    GRAVID
# 3         2017    m    45345  100XX W OHARE AIRPORT   169    GRAVID
# 4         2016    l    44169            4XX W 127TH   106    GRAVID
#
#                 TEST DATE  NUMBER OF MOSQUITOES    RESULT  \
# 0  09/25/2014 12:09:00 AM                     8  negative
# 1  09/15/2016 12:09:00 AM                    39  negative
# 2  08/17/2017 12:08:00 AM                    50  positive
# 3  08/17/2017 12:08:00 AM                    17  positive
# 4  09/15/2016 12:09:00 AM                    12  negative
#
#                   SPECIES  LATITUDE  LONGITUDE LOCATION
# 0  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 1  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 2  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 3  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN
# 4  CULEX PIPIENS/RESTUANS       NaN        NaN      NaN

# %% [markdown]
# ## **Finding all missing letters in Third attribute.**

# %%
df['TEST ID']
# Out:
# 0        40542
# 1        44219
# 2        45351
# 3        45345
# 4        44169
#          ...
# 29484    21734
# 29485    27885
# 29486    36525
# 29487    22451
# 29488    42348
# Name: TEST ID, Length: 29489, dtype: int64

# %%
df['TEST ID'].dtype
# Out:
# dtype('int64')

# %%
df['TEST ID'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29484    False
# 29485    False
# 29486    False
# 29487    False
# 29488    False
# Name: TEST ID, Length: 29489, dtype: bool

# %%
bool_series = pd.isnull(df["TEST ID"])
df[bool_series]
# Out:
# Empty DataFrame
# Columns: [SEASON YEAR, WEEK, TEST ID, BLOCK, TRAP, TRAP_TYPE, TEST DATE, NUMBER OF MOSQUITOES, RESULT, SPECIES, LATITUDE, LONGITUDE, LOCATION]
# Index: []

# %% [markdown]
# From the above code i didn't find any null missing values in the third attribute(TEST ID).

# %% [markdown]
# ##  **Five point summary**

# %%
df['SEASON YEAR'].describe()
# Out:
# count    29489.000000
# mean      2012.502018
# std          3.802700
# min       2007.000000
# 25%       2009.000000
# 50%       2012.000000
# 75%       2016.000000
# max       2019.000000
# Name: SEASON YEAR, dtype: float64

# %% [markdown]
# ## **Splitting the dataset into 60% training set and 40% test set with sampling**

# %%
sample=df.sample(frac=0.4, replace=True, random_state=1)
sample.shape
# Out:
# (11796, 13)

# %%
sample
# Out:
#        SEASON YEAR WEEK  TEST ID                  BLOCK  TRAP TRAP_TYPE  \
# 235           2017    m    45565          100XX W OHARE   173    GRAVID
# 12172         2015    m    41952      67XX S KEDZIE AVE    57    GRAVID
# 5192          2013   xs    35680  100XX W OHARE AIRPORT   185    GRAVID
# 17289         2011    m    32245  51XX N MONT CLARE AVE   149    GRAVID
# 10955         2011    s    31858  36XX N PITTSBURGH AVE    13    GRAVID
# ...            ...  ...      ...                    ...   ...       ...
# 23763         2007    s    21758        35XX W 116TH ST   127    GRAVID
# 11353         2014    m    39665         10XX E 67TH ST    64    GRAVID
# 2108          2019    m    48966  100XX W OHARE AIRPORT   185    GRAVID
# 9158          2008   xs    24284     70XX N MOSELLE AVE    10    GRAVID
# 18228         2013    l    37762    70XX W ARMITAGE AVE   120    GRAVID
#
#                     TEST DATE  NUMBER OF MOSQUITOES    RESULT  \
# 235    08/31/2017 12:08:00 AM                    20  positive
# 12172  08/26/2015 12:08:00 AM                     6  negative
# 5192   06/14/2013 12:06:00 AM                    34  negative
# 17289  08/26/2011 12:08:00 AM                     5  positive
# 10955  08/05/2011 12:08:00 AM                    18  negative
# ...                       ...                   ...       ...
# 23763  08/07/2007 12:08:00 AM                    29  negative
# 11353  08/21/2014 12:08:00 AM                    50  negative
# 2108   08/08/2019 12:08:00 AM                     2  negative
# 9158   07/01/2008 12:07:00 AM                     4  negative
# 18228  09/19/2013 12:09:00 AM                     9  negative
#
#                       SPECIES   LATITUDE  LONGITUDE  \
# 235    CULEX PIPIENS/RESTUANS        NaN        NaN
# 12172  CULEX PIPIENS/RESTUANS  41.771199 -87.703107
# 5192           CULEX RESTUANS        NaN        NaN
# 17289  CULEX PIPIENS/RESTUANS  41.974523 -87.804589
# 10955  CULEX PIPIENS/RESTUANS  41.945961 -87.832942
# ...                       ...        ...        ...
# 23763  CULEX PIPIENS/RESTUANS  41.682180 -87.710092
# 11353  CULEX PIPIENS/RESTUANS  41.773085 -87.600168
# 2108            CULEX PIPIENS        NaN        NaN
# 9158           CULEX RESTUANS  42.007998 -87.778235
# 18228          CULEX RESTUANS  41.916135 -87.801093
#
#                                        LOCATION
# 235                                         NaN
# 12172   (41.77119858797388, -87.70310660774493)
# 5192                                        NaN
# 17289  (41.974522761157274, -87.80458946950488)
# 10955   (41.94596109447193, -87.83294247349616)
# ...                                         ...
# 23763    (41.6821804028987, -87.71009165099498)
# 11353  (41.773085401492715, -87.60016755939222)
# 2108                                        NaN
# 9158   (42.007997503125345, -87.77823496507851)
# 18228   (41.91613471854847, -87.80109280863755)
#
# [11796 rows x 13 columns]

# %% [markdown]
# ## **Splitting the dataset into 75% training set and 25% test set with crossvalidation**

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,:12] # all parameters
y=df['NUMBER OF MOSQUITOES']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25) 
print("X_train shape: {}".format(X_train.shape))
print("X_test shape: {}".format(X_test.shape))
# Out:
# X_train shape: (22116, 12)
# X_test shape: (7373, 12)

# %%
x
# Out:
#        SEASON YEAR WEEK  TEST ID                      BLOCK  TRAP TRAP_TYPE  \
# 0             2014   xl    40542      100XX W OHARE AIRPORT   171    GRAVID
# 1             2016    l    44219      100XX W OHARE AIRPORT   171    GRAVID
# 2             2017    m    45351      100XX W OHARE AIRPORT   174    GRAVID
# 3             2017    m    45345      100XX W OHARE AIRPORT   169    GRAVID
# 4             2016    l    44169                4XX W 127TH   106    GRAVID
# ...            ...  ...      ...                        ...   ...       ...
# 29484         2007    s    21734            22XX W 113TH ST    78    GRAVID
# 29485         2009    m    27885         58XX N WESTERN AVE    24    GRAVID
# 29486         2013    s    36525  109XX S COTTAGE GROVE AVE    96    GRAVID
# 29487         2007    m    22451          73XX S CICERO AVE    58    GRAVID
# 29488         2015   xl    42348         14XX N HUMBOLDT DR    29    GRAVID
#
#                     TEST DATE  NUMBER OF MOSQUITOES    RESULT  \
# 0      09/25/2014 12:09:00 AM                     8  negative
# 1      09/15/2016 12:09:00 AM                    39  negative
# 2      08/17/2017 12:08:00 AM                    50  positive
# 3      08/17/2017 12:08:00 AM                    17  positive
# 4      09/15/2016 12:09:00 AM                    12  negative
# ...                       ...                   ...       ...
# 29484  08/07/2007 12:08:00 AM                    23  negative
# 29485  08/25/2009 12:08:00 AM                     1  negative
# 29486  07/25/2013 12:07:00 AM                     6  negative
# 29487  08/21/2007 12:08:00 AM                     6  negative
# 29488  09/30/2015 12:09:00 AM                     6  negative
#
#                       SPECIES   LATITUDE  LONGITUDE
# 0      CULEX PIPIENS/RESTUANS        NaN        NaN
# 1      CULEX PIPIENS/RESTUANS        NaN        NaN
# 2      CULEX PIPIENS/RESTUANS        NaN        NaN
# 3      CULEX PIPIENS/RESTUANS        NaN        NaN
# 4      CULEX PIPIENS/RESTUANS        NaN        NaN
# ...                       ...        ...        ...
# 29484  CULEX PIPIENS/RESTUANS  41.688171 -87.678252
# 29485  CULEX PIPIENS/RESTUANS  41.987245 -87.689417
# 29486          CULEX RESTUANS  41.695494 -87.609082
# 29487  CULEX PIPIENS/RESTUANS  41.760082 -87.741607
# 29488  CULEX PIPIENS/RESTUANS  41.907285 -87.701395
#
# [29489 rows x 12 columns]

# %% [markdown]
# ## **Picking the 3 most important attributes and make a correlation matrix**

# %%
df2 = pd.DataFrame(df, columns = ['SEASON YEAR', 'TEST ID', 'NUMBER OF MOSQUITOES'])

# %%
corr = df2.corr()
corr
# Out:
#                       SEASON YEAR   TEST ID  NUMBER OF MOSQUITOES
# SEASON YEAR              1.000000  0.994706             -0.018555
# TEST ID                  0.994706  1.000000             -0.022352
# NUMBER OF MOSQUITOES    -0.018555 -0.022352              1.000000

# %% [markdown]
# ## **Performaning Random Forest Model**

# %%
df3= pd.DataFrame(df, columns = ['SEASON YEAR', 'TEST ID', 'NUMBER OF MOSQUITOES','RESULT'])

# %%
from sklearn.model_selection import train_test_split
x=df3.iloc[:,:3] # all parameters
y=df3['RESULT'] # class labels 'southwest', 'southeast', 'northwest', 'northeast'
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25) 
print("X_train shape: {}".format(X_train.shape))
print("X_test shape: {}".format(X_test.shape))
# Out:
# X_train shape: (22116, 3)
# X_test shape: (7373, 3)

# %%
rf = RandomForestClassifier()
rf.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestClassifier()>

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9076359690763597
